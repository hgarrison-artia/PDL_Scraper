# %%
import pandas as pd
import docx

# %%
doc_path = 'OR PDL.docx' 
doc = docx.Document(doc_path)

# %%
all_rows = []

for table in doc.tables:
    for row in table.rows:
        row_data = [cell.text.strip() for cell in row.cells]
        all_rows.append(row_data)


df = pd.DataFrame(all_rows)


df[0] = df[0].replace('', pd.NA).ffill()
df[1] = df[1].replace('', pd.NA).ffill()

# Combine columns 2 and 3 (index 1 and 2), separated by a space, and store in column 1
df[2] = df[2].astype(str).str.strip() + ' ' + df[3].astype(str).str.strip()

# (Optional) Drop column 2 if you no longer need it
df = df.drop(columns=[3])
df['Status'] = 'Preferred'
df = df.iloc[1:].reset_index(drop=True)
df[0] = df[0].astype(str).str.strip() + ': ' + df[1].astype(str).str.strip()
df = df.drop(columns=[1])

df.columns = ['therapeutic_class', 'pdl_name', 'status']
df = df[~df['therapeutic_class'].str.strip().str.startswith('System')].reset_index(drop=True)
df['pdl_name'] = [name.replace("\n", " ") for name in df['pdl_name']]
df['therapeutic_class'] = [name.replace("\n", " ") for name in df['therapeutic_class']]

# %%
df.to_csv('OR_PDL.csv', index=False)

# %%
df.head(50)
# Out:
#                                     therapeutic_class  \
# 0                    Allergy/Cold: Anaphylaxis Rescue
# 1                    Allergy/Cold: Anaphylaxis Rescue
# 2     Allergy/Cold: Antihistamines, Second Generation
# 3     Allergy/Cold: Antihistamines, Second Generation
# 4     Allergy/Cold: Antihistamines, Second Generation
# 5     Allergy/Cold: Antihistamines, Second Generation
# 6                        Allergy/Cold: Cough and Cold
# 7                        Allergy/Cold: Cough and Cold
# 8                        Allergy/Cold: Cough and Cold
# 9                        Allergy/Cold: Cough and Cold
# 10                       Allergy/Cold: Cough and Cold
# 11                       Allergy/Cold: Cough and Cold
# 12                       Allergy/Cold: Cough and Cold
# 13                       Allergy/Cold: Cough and Cold
# 14                       Allergy/Cold: Cough and Cold
# 15                       Allergy/Cold: Cough and Cold
# 16                       Allergy/Cold: Cough and Cold
# 17                       Allergy/Cold: Cough and Cold
# 18                       Allergy/Cold: Cough and Cold
# 19                       Allergy/Cold: Cough and Cold
# 20                       Allergy/Cold: Cough and Cold
# 21                       Allergy/Cold: Cough and Cold
# 22                       Allergy/Cold: Cough and Cold
# 23                       Allergy/Cold: Cough and Cold
# 24                       Allergy/Cold: Cough and Cold
# 25                       Allergy/Cold: Cough and Cold
# 26                Allergy/Cold: Hereditary Angioedema
# 27                Allergy/Cold: Hereditary Angioedema
# 28               Allergy/Cold: Nasal Allergy Inhalers
# 29                        Analgesics: CGRP Inhibitors
# 30                        Analgesics: CGRP Inhibitors
# 31                        Analgesics: CGRP Inhibitors
# 32                        Analgesics: CGRP Inhibitors
# 33                                   Analgesics: Gout
# 34                                   Analgesics: Gout
# 35                                   Analgesics: Gout
# 36                 Analgesics: Muscle Relaxants, Oral
# 37                 Analgesics: Muscle Relaxants, Oral
# 38                 Analgesics: Muscle Relaxants, Oral
# 39                 Analgesics: Muscle Relaxants, Oral
# 40  Analgesics: Non-Steroidal Anti- Inflammatory D...
#