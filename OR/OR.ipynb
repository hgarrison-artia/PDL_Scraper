# %%
import pandas as pd
import docx

# %%
doc_path = 'OR.docx' 
doc = docx.Document(doc_path)

# %%
all_rows = []

for table in doc.tables:
    for row in table.rows:
        row_data = [cell.text.strip() for cell in row.cells]
        all_rows.append(row_data)


df = pd.DataFrame(all_rows)


df[0] = df[0].replace('', pd.NA).ffill()
df[1] = df[1].replace('', pd.NA).ffill()

# Combine columns 2 and 3 (index 1 and 2), separated by a space, and store in column 1
df[2] = df[2].astype(str).str.strip() + ' ' + df[3].astype(str).str.strip()

# (Optional) Drop column 2 if you no longer need it
df = df.drop(columns=[3])
df['Status'] = 'Preferred'
df = df.iloc[1:].reset_index(drop=True)
df[0] = df[0].astype(str).str.strip() + ': ' + df[1].astype(str).str.strip()
df = df.drop(columns=[1])

df.columns = ['therapeutic_class', 'pdl_name', 'status']
df = df[~df['therapeutic_class'].str.strip().str.startswith('System')].reset_index(drop=True)
df['pdl_name'] = [name.replace("\n", " ") for name in df['pdl_name']]
df['therapeutic_class'] = [name.replace("\n", " ") for name in df['therapeutic_class']]

# %%
df.to_csv('OR_PDL.csv', index=False)

# %%
df.head(50)
# Out:
#                                     therapeutic_class  \
# 0                    Allergy/Cold: Anaphylaxis Rescue
# 1     Allergy/Cold: Antihistamines, Second Generation
# 2     Allergy/Cold: Antihistamines, Second Generation
# 3     Allergy/Cold: Antihistamines, Second Generation
# 4     Allergy/Cold: Antihistamines, Second Generation
# 5                        Allergy/Cold: Cough and Cold
# 6                 Allergy/Cold: Hereditary Angioedema
# 7                Allergy/Cold: Nasal Allergy Inhalers
# 8                         Analgesics: CGRP Inhibitors
# 9                                    Analgesics: Gout
# 10                 Analgesics: Muscle Relaxants, Oral
# 11  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 12  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 13  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 14  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 15  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 16  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 17  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 18  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 19  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 20  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 21  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 22  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 23  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 24  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 25  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 26  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 27  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 28  Analgesics: Non-Steroidal Anti- Inflammatory D...
# 29                   Analgesics: Opioids, Long-Acting
# 30                  Analgesics: Opioids, Short-Acting
# 31              Analgesics: Pain Medications, Topical
# 32              Analgesics: Serotonin Agonists, Nasal
# 33               Analgesics: Serotonin Agonists, Oral
# 34       Analgesics: Serotonin Agonists, Subcutaneous
# 35     Antibiotics: Amoxicillin and Clavulanate, Oral
# 36                  Antibiotics: Antibiotics, Vaginal
# 37        Antibiotics: Cephalosporins (1st Gen), Oral
# 38        Antibiotics: Cephalosporins (2nd Gen), Oral
# 39        Antibiotics: Cephalosporins (3rd Gen), Oral
# 40        Antibiotics: Clostridioides difficile Drugs
# 41                Antibiotics: Fluoroquinolones, Oral
# 42                      Antibiotics: Macrolides, Oral
# 43                  Antibiotics: Oxazolidinones, Oral
# 44                   Antibiotics: Tetracyclines, Oral
# 45                      Antifungal: Antifungals, Oral
# 46                   Antifungal: Antifungals, Vaginal
# 47                 Antivirals: Coronavirus Antivirals
# 48                            Antivirals: Hepatitis B
# 49  Antivirals: Hepatitis C, Direct-Acting Antivirals
#
#                                              pdl_name     status
