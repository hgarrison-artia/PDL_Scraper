# %%
import pandas as pd

df = pd.read_excel('FL.xlsx')

df.columns = ['HIC', 'Therapeutic Class', 'Label Name', 'Generic Name', 'Min Age', 'Max Age', 'PA']

df = df[5:].reset_index(drop=True)

df
# Out:
#       HIC                      Therapeutic Class  \
# 0     A1A                   DIGITALIS GLYCOSIDES
# 1     NaN                                    NaN
# 2     NaN                                    NaN
# 3     NaN                                    NaN
# 4     NaN                                    NaN
# ...   ...                                    ...
# 4487  NaN                                    NaN
# 4488  Z4B       LEUKOTRIENE RECEPTOR ANTAGONISTS
# 4489  NaN                                    NaN
# 4490  NaN                                    NaN
# 4491  Z9D  DIAGNOSTIC PREPARATIONS,MISCELLANEOUS
#
#                          Label Name         Generic Name Min Age Max Age  \
# 0       DIGOXIN 0.05 MG/ML SOLUTION              DIGOXIN     Yes     999
# 1           DIGOXIN 0.125 MG TABLET              DIGOXIN       0     999
# 2            DIGOXIN 0.25 MG TABLET              DIGOXIN       0     999
# 3            DIGOXIN 125 MCG TABLET              DIGOXIN       0     999
# 4            DIGOXIN 250 MCG TABLET              DIGOXIN       0     999
# ...                             ...                  ...     ...     ...
# 4487            XELJANZ 5 MG TABLET  TOFACITINIB CITRATE       2     999
# 4488   MONTELUKAST SOD 10 MG TABLET   MONTELUKAST SODIUM       0     999
# 4489  MONTELUKAST SOD 4 MG TAB CHEW   MONTELUKAST SODIUM       0     999
# 4490  MONTELUKAST SOD 5 MG TAB CHEW   MONTELUKAST SODIUM       0     999
# 4491             GLUCAGON 1 MG VIAL         GLUCAGON HCL       0     999
#
#            PA
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
# ...       ...
# 4487  Auto PA
# 4488       No
# 4489       No
# 4490       No
# 4491       No
#
# [4492 rows x 7 columns]

# %%
last_class = ''

for _, row in df.iterrows():
    if pd.isna(df.loc[_, 'Therapeutic Class']):
        df.loc[_, 'Therapeutic Class'] = last_class
    else:
        last_class = df.loc[_, 'Therapeutic Class']
    
df
# Out:
#       HIC                      Therapeutic Class  \
# 0     A1A                   DIGITALIS GLYCOSIDES
# 1     NaN                   DIGITALIS GLYCOSIDES
# 2     NaN                   DIGITALIS GLYCOSIDES
# 3     NaN                   DIGITALIS GLYCOSIDES
# 4     NaN                   DIGITALIS GLYCOSIDES
# ...   ...                                    ...
# 4487  NaN          JANUS KINASE (JAK) INHIBITORS
# 4488  Z4B       LEUKOTRIENE RECEPTOR ANTAGONISTS
# 4489  NaN       LEUKOTRIENE RECEPTOR ANTAGONISTS
# 4490  NaN       LEUKOTRIENE RECEPTOR ANTAGONISTS
# 4491  Z9D  DIAGNOSTIC PREPARATIONS,MISCELLANEOUS
#
#                          Label Name         Generic Name Min Age Max Age  \
# 0       DIGOXIN 0.05 MG/ML SOLUTION              DIGOXIN     Yes     999
# 1           DIGOXIN 0.125 MG TABLET              DIGOXIN       0     999
# 2            DIGOXIN 0.25 MG TABLET              DIGOXIN       0     999
# 3            DIGOXIN 125 MCG TABLET              DIGOXIN       0     999
# 4            DIGOXIN 250 MCG TABLET              DIGOXIN       0     999
# ...                             ...                  ...     ...     ...
# 4487            XELJANZ 5 MG TABLET  TOFACITINIB CITRATE       2     999
# 4488   MONTELUKAST SOD 10 MG TABLET   MONTELUKAST SODIUM       0     999
# 4489  MONTELUKAST SOD 4 MG TAB CHEW   MONTELUKAST SODIUM       0     999
# 4490  MONTELUKAST SOD 5 MG TAB CHEW   MONTELUKAST SODIUM       0     999
# 4491             GLUCAGON 1 MG VIAL         GLUCAGON HCL       0     999
#
#            PA
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
# ...       ...
# 4487  Auto PA
# 4488       No
# 4489       No
# 4490       No
# 4491       No
#
# [4492 rows x 7 columns]

# %%
df = df[['Therapeutic Class', 'Label Name']]
df.columns = ['therapeutic_class', 'pdl_name']
df['status'] = 'Preferred'
df
# Out:
#                           therapeutic_class                       pdl_name  \
# 0                      DIGITALIS GLYCOSIDES    DIGOXIN 0.05 MG/ML SOLUTION
# 1                      DIGITALIS GLYCOSIDES        DIGOXIN 0.125 MG TABLET
# 2                      DIGITALIS GLYCOSIDES         DIGOXIN 0.25 MG TABLET
# 3                      DIGITALIS GLYCOSIDES         DIGOXIN 125 MCG TABLET
# 4                      DIGITALIS GLYCOSIDES         DIGOXIN 250 MCG TABLET
# ...                                     ...                            ...
# 4487          JANUS KINASE (JAK) INHIBITORS            XELJANZ 5 MG TABLET
# 4488       LEUKOTRIENE RECEPTOR ANTAGONISTS   MONTELUKAST SOD 10 MG TABLET
# 4489       LEUKOTRIENE RECEPTOR ANTAGONISTS  MONTELUKAST SOD 4 MG TAB CHEW
# 4490       LEUKOTRIENE RECEPTOR ANTAGONISTS  MONTELUKAST SOD 5 MG TAB CHEW
# 4491  DIAGNOSTIC PREPARATIONS,MISCELLANEOUS             GLUCAGON 1 MG VIAL
#
#          status
# 0     Preferred
# 1     Preferred
# 2     Preferred
# 3     Preferred
# 4     Preferred
# ...         ...
# 4487  Preferred
# 4488  Preferred
# 4489  Preferred
# 4490  Preferred
# 4491  Preferred
#
# [4492 rows x 3 columns]
